# %%
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

rawData = pd.read_csv('SpotComparisonDataCleaner.csv')
# Out:
# /Users/aditya/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:1130: DtypeWarning: Columns (9,10,13,17,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
rawData.head()
# Out:
#   Client Campaign         Type Quarter Operator Cluster Network      Date  \
# 0    UFC      171  VOD Tune-In      Q1  Charter     NaN  TRAVEL  3/6/2014
# 1    UFC      171  VOD Tune-In      Q1  Charter     NaN     AMC  3/6/2014
# 2    UFC      171  VOD Tune-In      Q1  Charter     NaN   TRUTV  3/6/2014
# 3    UFC      171  VOD Tune-In      Q1  Charter     NaN  NATGEO  3/6/2014
# 4    UFC      171  VOD Tune-In      Q1  Charter     NaN  NATGEO  3/6/2014
#
#   Day of Week Start Time    ...     Deliv Demo 1 Imps Deliv Demo 2 Imps  \
# 0    Thursday        NaN    ...           4576.819300       4480.493122
# 1    Thursday        NaN    ...           1451.634054       1385.347946
# 2    Thursday        NaN    ...           2184.095818       1862.947131
# 3    Thursday        NaN    ...           2333.683923       2110.319009
# 4    Thursday        NaN    ...           1924.067988       1815.095413
#
#   Deliv Demo 3 Imps Deliv Demo 4 Imps  Deliv Demo 1 Pct Deliv Demo 2 Pct  \
# ...

# %%
rawData.columns
# Out:
# Index([u'Client', u'Campaign', u'Type', u'Quarter', u'Operator', u'Cluster', u'Network', u'Date', u'Day of Week', u'Start Time', u'End Time', u'Daypart', u'Purchased SM Daypart', u'Mirror Flag', u'Purchased Units', u'Demo 1 Name', u'Demo 2 Name', u'Demo 3 Name', u'Demo 4 Name', u'Pur Ratecard HH Imps', u'Pur Disc HH Imps', u'Pur P2+ Imps', u'Pur Demo 1 Imps', u'Pur Demo 2 Imps', u'Pur Demo 3 Imps', u'Pur Demo 4 Imps', u'AirDateTime', u'Deliv SM Daypart', u'Delivered Units', u'Deliv HH Imps', u'Deliv P2+ Imps', u'Deliv Demo 1 Imps', u'Deliv Demo 2 Imps', u'Deliv Demo 3 Imps', u'Deliv Demo 4 Imps', u'Deliv Demo 1 Pct', u'Deliv Demo 2 Pct', u'Deliv Demo 3 Pct', u'Deliv Demo 4 Pct', u'justTime_num', u'planStart'], dtype='object')

# %%
set(rawData['Start Time'])
# Out:
# {nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  0.41666666700000005,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...
