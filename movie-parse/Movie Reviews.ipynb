# %%
import pandas as pd

# %%
movies_reviews = pd.read_csv('parsedmoviefile.txt', sep='\t')

# %%
movies_reviews.head()
# Out:
#   product/productId                                        review/text  \
# 0        B003AI2VGA  Synopsis: On the daily trek from Juarez, Mexic...
# 1        B003AI2VGA  THE VIRGIN OF JUAREZ is based on true events s...
# 2        B003AI2VGA  The scenes in this film can be very disquietin...
# 3        B003AI2VGA  THE VIRGIN OF JUAREZ (2006)<br />directed by K...
# 4        B003AI2VGA  Informationally, this SHOWTIME original is ess...
#
#    review/helpfulness  review/score  ASIN  Text Helpfulness HCount  \
# 0                 1.0             7     3     0       ln[0]  ln[1]
# 1                 1.0             4     3     0       ln[0]  ln[1]
# 2                 0.8            10     5     0       ln[0]  ln[1]
# 3                 1.0             1     3     0       ln[0]  ln[1]
# 4                 1.0             1     3     0       ln[0]  ln[1]
#
#                Score
# 0  ln[2]\ln[3]\ln[4]
# 1  ln[2]\ln[3]\ln[4]
# 2  ln[2]\ln[3]\ln[4]
# 3  ln[2]\ln[3]\ln[4]
# 4  ln[2]\ln[3]\ln[4]
# ...

# %%
movies_reviews[['product/productId', 'review/score']]
# Out:
#    product/productId  review/score
# 0         B003AI2VGA             3
# 1         B003AI2VGA             3
# 2         B003AI2VGA             5
# 3         B003AI2VGA             3
# 4         B003AI2VGA             3
# 5         B003AI2VGA             2
# 6         B003AI2VGA             1
# 7         B00006HAXW             5
# 8         B00006HAXW             5
# 9         B00006HAXW             5
# 10        B00006HAXW             4
# 11        B00006HAXW             5
# 12        B00006HAXW             5
# 13        B00006HAXW             5
# 14        B00006HAXW             4
# 15        B00006HAXW             5
# 16        B00006HAXW             5
# 17        B00006HAXW             5
# 18        B00006HAXW             5
# 19        B00006HAXW             5
# 20        B00004CQT3             5
# 21        B00004CQT3             5
# 22        B00004CQT3             5
# 23        B00004CQT3             5
# 24        B00004CQT3             5
# 25        B00004CQT3             5
# ...

# %%
movies_reviews['review/score'] > 4
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# ...
# 5539    False
# 5540    False
# 5541     True
# 5542     True
# 5543     True
# 5544    False
# 5545    False
# 5546    False
# 5547    False
# 5548    False
# 5549    False
# 5550     True
# 5551    False
# 5552     True
# 5553     True
# Name: review/score, Length: 5554, dtype: bool

# %%
movies_reviews[movies_reviews['review/score'] > 4]
# Out:
#    product/productId                                        review/text  \
# 2         B003AI2VGA  The scenes in this film can be very disquietin...
# 7         B00006HAXW  Over the past few years, public television has...
# 8         B00006HAXW  I recvd this video (DVD version) as a Christma...
# 9         B00006HAXW  Wow! When I saw this show on PBS--that was it,...
# 11        B00006HAXW  Having worked in television for 34 years I can...
# 12        B00006HAXW  The people who have reviewed this DVD before m...
# 13        B00006HAXW  I have all of the doo wop DVD's and this one i...
# 15        B00006HAXW  Get it, also get Dop Wop 50 and Doo Wop 51. Ea...
# 16        B00006HAXW  Excellent, excellent performers. Excellent vid...
# 17        B00006HAXW  This video is awesome and of particular intere...
# 18        B00006HAXW  As I stated in my reviews for Doo Wop 50 and D...
# 19        B00006HAXW  I own both the VHS and DVD versions of this pr...
# ...

# %% [raw]
# Only selects rows where the condition is true
